# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
from plot_config import *

# %%
rerun = True
regen_talk = False

# %%
# if rerun:
#     # for time_slice in [slice(1824,None,-1)]:
#     for time_slice in [slice(1824,None,-1),slice(None,None,-1)]:

#         particle_path = '/sciserver/filedb08-01/ocean/wenrui_temp/particle_file/saltyM/'
#         pre = 'lineplotprep/salty_'
#         # particle_path = '/sciserver/filedb11-01/ocean/wenrui_temp/particle_file/holliday/'
#         table_path = particle_path+'tableN/'
#         map_path = particle_path+'mapsN/'
#         maps = xr.open_zarr(map_path)
#         table= xr.open_zarr(table_path)
        
#         cum = table.isel(time = time_slice).cumsum(dim = 'time')
        
#         size = len(cum.time)
        
#         mean = cum.mean(dim = 'space')
#         std = cum.std(dim = 'space')
        
#         for var in mean.data_vars:
#             print(var, end = ' ')
#             mean[var] = mean[var].chunk(size)
#             # if var in ['sl','sf']:
#             #     mean['var'] = table.isel(time = time_slice).mean(dim = 'space').chunk(size)
#         for var in std.data_vars:
#             print(var, end = ' ')
#             std[var] = std[var].chunk(size)
        
#         mean.to_zarr(pre+'mean'+str(time_slice),mode = 'w')
#         std.to_zarr(pre+'std'+str(time_slice),mode = 'w')
#         print()
        
        
        
        
        
#         particle_path = '/sciserver/filedb04-01/ocean/wenrui_temp/particle_file/freshM/'
#         pre = 'lineplotprep/fresh_'
#         # particle_path = '/sciserver/filedb11-01/ocean/wenrui_temp/particle_file/holliday/'
#         table_path = particle_path+'tableN/'
#         map_path = particle_path+'mapsN/'
#         maps = xr.open_zarr(map_path)
#         table= xr.open_zarr(table_path)
        
#         cum = table.isel(time = time_slice).cumsum(dim = 'time')
        
#         size = len(cum.time)
        
#         mean = cum.mean(dim = 'space')
#         std = cum.std(dim = 'space')
        
#         for var in mean.data_vars:
#             print(var, end = ' ')
#             mean[var] = mean[var].chunk(size)
#             # if var in ['sl','sf']:
#             #     mean['var'] = table.isel(time = time_slice).mean(dim = 'space').chunk(size)
#         for var in std.data_vars:
#             print(var, end = ' ')
#             std[var] = std[var].chunk(size)

#         mean.to_zarr(pre+'mean'+str(time_slice),mode = 'w')
#         std.to_zarr(pre+'std'+str(time_slice),mode = 'w')
#         print()

# %%
if rerun:
    # for time_slice in [slice(1824,None,-1)]:
    time_slice = slice(1824,None,-1)

    particle_path = '/sciserver/filedb08-01/ocean/wenrui_temp/particle_file/saltyM/'
    pre = 'lineplotprep/salty_mean_traj_'
    # particle_path = '/sciserver/filedb11-01/ocean/wenrui_temp/particle_file/holliday/'
    table_path = particle_path+'mean_traj_table/'
    map_path = particle_path+'mean_traj_maps/'
    # maps = xr.open_zarr(map_path)
    table= xr.open_zarr(table_path)
    
    cum = table.isel(time = time_slice).cumsum(dim = 'time')
    
    size = len(cum.time)
    
    mean = cum.mean(dim = 'space')
    std = cum.std(dim = 'space')
    
    for var in mean.data_vars:
        print(var, end = ' ')
        mean[var] = mean[var].chunk(size)
        # if var in ['sl','sf']:
        #     mean['var'] = table.isel(time = time_slice).mean(dim = 'space').chunk(size)
    for var in std.data_vars:
        print(var, end = ' ')
        std[var] = std[var].chunk(size)
    
    mean.to_zarr(pre+'mean'+str(time_slice),mode = 'w')
    std.to_zarr(pre+'std'+str(time_slice),mode = 'w')
    print()
# Out:
# A E F I dep dif_h dif_v e_ua lat lhs lon sf sl A E F I dep dif_h dif_v e_ua lat lhs lon sf sl

# %%
if rerun:
    # for time_slice in [slice(1824,None,-1)]:
    time_slice = slice(1824,None,-1)

    particle_path = '/sciserver/filedb04-01/ocean/wenrui_temp/particle_file/freshM/'
    pre = 'lineplotprep/fresh_mean_traj_'
    # particle_path = '/sciserver/filedb11-01/ocean/wenrui_temp/particle_file/holliday/'
    table_path = particle_path+'mean_traj_table/'
    map_path = particle_path+'mean_traj_maps/'
    # maps = xr.open_zarr(map_path)
    table= xr.open_zarr(table_path)
    
    cum = table.isel(time = time_slice).cumsum(dim = 'time')
    
    size = len(cum.time)
    
    mean = cum.mean(dim = 'space')
    std = cum.std(dim = 'space')
    
    for var in mean.data_vars:
        print(var, end = ' ')
        mean[var] = mean[var].chunk(size)
        # if var in ['sl','sf']:
        #     mean['var'] = table.isel(time = time_slice).mean(dim = 'space').chunk(size)
    for var in std.data_vars:
        print(var, end = ' ')
        std[var] = std[var].chunk(size)
    
    mean.to_zarr(pre+'mean'+str(time_slice),mode = 'w')
    std.to_zarr(pre+'std'+str(time_slice),mode = 'w')
    print()
# Out:
# A E F I dep dif_h dif_v e_ua lat lhs lon sf sl A E F I dep dif_h dif_v e_ua lat lhs lon sf sl

# %%
if rerun:
    # for time_slice in [slice(1824,None,-1)]:
    time_slice = slice(1824,None,-1)
    for year in [2001,2012]:
        for the_traj in ['time','mean']:

            particle_path = f'/sciserver/filedb08-01/ocean/wenrui_temp/particle_file/neutral{year}/'
            pre = f'lineplotprep/neutral{year}_{the_traj}_traj_'
            # particle_path = '/sciserver/filedb11-01/ocean/wenrui_temp/particle_file/holliday/'
            table_path = particle_path+f'{the_traj}_traj_table/'
            map_path = particle_path+f'{the_traj}_traj_maps/'
            # maps = xr.open_zarr(map_path)
            table= xr.open_zarr(table_path)
            
            cum = table.isel(time = time_slice).cumsum(dim = 'time')
            
            size = len(cum.time)
            
            mean = cum.mean(dim = 'space')
            std = cum.std(dim = 'space')
            
            for var in mean.data_vars:
                print(var, end = ' ')
                mean[var] = mean[var].chunk(size)
                # if var in ['sl','sf']:
                #     mean['var'] = table.isel(time = time_slice).mean(dim = 'space').chunk(size)
            for var in std.data_vars:
                print(var, end = ' ')
                std[var] = std[var].chunk(size)
            
            mean.to_zarr(pre+'mean'+str(time_slice),mode = 'w')
            std.to_zarr(pre+'std'+str(time_slice),mode = 'w')
            print()
# Out:
# A E F I dep dif_h dif_v e_ua lat lhs lon sf sl A E F I dep dif_h dif_v e_ua lat lhs lon sf sl
# A E F I dep dif_h dif_v e_ua lat lhs lon sf sl A E F I dep dif_h dif_v e_ua lat lhs lon sf sl
# A E F I dep dif_h dif_v e_ua lat lhs lon sf sl A E F I dep dif_h dif_v e_ua lat lhs lon sf sl
# A E F I dep dif_h dif_v e_ua lat lhs lon sf sl A E F I dep dif_h dif_v e_ua lat lhs lon sf sl

# %%
# table

# table_path = particle_path+'table/'
# table= xr.open_zarr(table_path).isel(space = slice(1000))
# table_path = particle_path+'tableN/'
# tablen= xr.open_zarr(table_path).isel(space = slice(1000))

# tablen['A'].max().values

# table['A'].max().values

# bins = 1
# vmax = 1e-3
# # plt.imshow(table['sf'][:,::bins],vmax = vmax ,vmin = -vmax,)
# plt.imshow(tablen['sl'][:,::bins])
# plt.colorbar()

# bins = 1
# vmax = 1e-3
# # plt.imshow(table['sf'][:,::bins],vmax = vmax ,vmin = -vmax,)
# plt.imshow(tablen['sf'][:,::bins])
# plt.colorbar()

# np.argmax(np.array(table['E']))

# ip = 100
# plt.plot(cum['A'][:,ip])

# plt.plot(cum['E'][:,ip])

# %% [markdown]
# # Let the plotting begin

# %%
just_for_time = '/sciserver/filedb10-01/ocean/wenrui_temp/vol_budget'

rtime = np.array(xr.open_zarr(just_for_time).time)

# %%
extra_text = 'The spread are enhanced 10 times'

# %%
if regen_talk:
    case = 'fresh'
    duration = 'five'
    save_as = 'talkfig1(b)0.png'
    plt.clf()
    pre = 'lineplotprep/'+case+'_'
    if duration == 'five':
        time_slice = slice(1824,None,-1)
    elif duration == 'ten':
        time_slice = slice(None,None,-1)
    else:
        raise ValueError('duration not precalculated')
    str_slc = str(time_slice)
    
    if case == 'salty':
        TOTAL_VOLUME,NUMBER_OF_PARTICLE,VOLUME_EACH,idate = TOTAL_VOLUME_salty,NUMBER_OF_PARTICLE_salty,VOLUME_EACH_salty,salty_idate
    if case == 'fresh':
        TOTAL_VOLUME,NUMBER_OF_PARTICLE,VOLUME_EACH,idate = TOTAL_VOLUME_fresh,NUMBER_OF_PARTICLE_fresh,VOLUME_EACH_fresh,fresh_idate
    mean = xr.open_zarr(pre+'mean'+str_slc)
    std = xr.open_zarr(pre+'std'+str_slc)
    xtime = rtime[idate:idate-len(mean.time):-1]
    
    ax = plt.axes()
    handles = []
    labels = []
    # for var in rhs_list:
    #     print(var)
    #     a_mean = -mean[var][::-1]
    #     a_std = 10*std[var][::-1]/np.sqrt(NUMBER_OF_PARTICLE-1)
    #     mean_line, = ax.plot(xtime, a_mean, label=case_term_dic[var], color=color_dic[var])
    #     spread_area = ax.fill_between(xtime, a_mean - a_std, a_mean + a_std, alpha=0.3, label=case_term_dic[var], color=color_dic[var])
    #     handles.append((mean_line, spread_area))
    #     labels.append(case_term_dic[var])
    # mean['tot'] = (mean['A']+mean['e_ua']+mean['E']+mean['dif_h']+mean['dif_v']+mean['I']+mean['F'])
    offset = float(mean['sf'][0])
    salt = np.diff(np.array([0]+list(mean['sl'].data)))
    # to_explain = salt - offset
    # error = to_explain + mean['tot']
    # mean_line, = ax.plot(xtime, error[::-1], color=error_color)
    # handles.append(mean_line)
    # labels.append('Error')
    
    if case == 'salty':
        sal_color = salty_theme_color
    elif case == 'fresh':
        sal_color = fresh_theme_color
    # invisible_line, = plt.plot([],[],c = 'none')
    legend = ax.legend(handles,labels,fontsize = 11,loc = 0)
    salt_line, = ax.plot(xtime, salt[::-1]-offset,color = sal_color)
    handles.append(salt_line)
    labels.append('Salinity Anomaly')
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim()[0] + offset, ax.get_ylim()[1] + offset)
    # legend.set_title(extra_text)
    # plt.setp(legend.get_title(),fontsize=7)
    if save_as:
        plt.savefig(save_as,dpi = dpi)

# %%
# ax.get_ylim()

# %%
# offset

# %%
if regen_talk:
    case = 'fresh'
    duration = 'five'
    save_as = 'talkfig1(b)1.png'
    plt.clf()
    pre = 'lineplotprep/'+case+'_'
    if duration == 'five':
        time_slice = slice(1824,None,-1)
    elif duration == 'ten':
        time_slice = slice(None,None,-1)
    else:
        raise ValueError('duration not precalculated')
    str_slc = str(time_slice)
    
    if case == 'salty':
        TOTAL_VOLUME,NUMBER_OF_PARTICLE,VOLUME_EACH,idate = TOTAL_VOLUME_salty,NUMBER_OF_PARTICLE_salty,VOLUME_EACH_salty,salty_idate
    if case == 'fresh':
        TOTAL_VOLUME,NUMBER_OF_PARTICLE,VOLUME_EACH,idate = TOTAL_VOLUME_fresh,NUMBER_OF_PARTICLE_fresh,VOLUME_EACH_fresh,fresh_idate
    mean = xr.open_zarr(pre+'mean'+str_slc)
    std = xr.open_zarr(pre+'std'+str_slc)
    xtime = rtime[idate:idate-len(mean.time):-1]
    
    ax = plt.axes()
    handles = []
    labels = []
    for var in rhs_list:
        print(var)
        a_mean = -mean[var][::-1]
        a_std = 10*std[var][::-1]/np.sqrt(NUMBER_OF_PARTICLE-1)
        mean_line, = ax.plot(xtime, a_mean, label=case_term_dic[var], color=color_dic[var])
        spread_area = ax.fill_between(xtime, a_mean - a_std, a_mean + a_std, alpha=0.3, label=case_term_dic[var], color=color_dic[var])
        handles.append((mean_line, spread_area))
        labels.append(case_term_dic[var])
    mean['tot'] = (mean['A']+mean['e_ua']+mean['E']+mean['dif_h']+mean['dif_v']+mean['I']+mean['F'])
    offset = float(mean['sf'][0])
    salt = np.diff(np.array([0]+list(mean['sl'].data)))
    # to_explain = salt - offset
    # error = to_explain + mean['tot']
    # mean_line, = ax.plot(xtime, error[::-1], color=error_color)
    # handles.append(mean_line)
    # labels.append('Error')
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim()[0] + offset, ax.get_ylim()[1] + offset)
    if case == 'salty':
        sal_color = salty_theme_color
    elif case == 'fresh':
        sal_color = fresh_theme_color
    salt_line, = ax.plot(xtime, salt[::-1]-offset,color = sal_color)
    handles.append(salt_line)
    labels.append('Salinity Anomaly')
    # invisible_line, = plt.plot([],[],c = 'none')
    legend = ax.legend(handles,labels,fontsize = 11,loc = 0)
    legend.set_title(extra_text)
    plt.setp(legend.get_title(),fontsize=11)
    if save_as:
        plt.savefig(save_as,dpi = dpi)

# %%
mean
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 3650)
# Dimensions without coordinates: time
# Data variables: (12/13)
#     A        (time) float64 dask.array<chunksize=(3650,), meta=np.ndarray>
#     E        (time) float64 dask.array<chunksize=(3650,), meta=np.ndarray>
#     F        (time) float64 dask.array<chunksize=(3650,), meta=np.ndarray>
#     I        (time) float64 dask.array<chunksize=(3650,), meta=np.ndarray>
#     dep      (time) float64 dask.array<chunksize=(3650,), meta=np.ndarray>
#     dif_h    (time) float64 dask.array<chunksize=(3650,), meta=np.ndarray>
#     ...       ...
#     e_ua     (time) float64 dask.array<chunksize=(3650,), meta=np.ndarray>
#     lat      (time) float64 dask.array<chunksize=(3650,), meta=np.ndarray>
#     lhs      (time) float64 dask.array<chunksize=(3650,), meta=np.ndarray>
#     lon      (time) float64 dask.array<chunksize=(3650,), meta=np.ndarray>
#     sf       (time) float64 dask.array<chunksize=(3650,), meta=np.ndarray>
#     sl       (time) float64 dask.array<chunksize=(3650,), meta=np.ndarray>

# %%
meta = [
    ('fresh','five','figure1(b).png'),
    # ('salty','five','figure4(b).png'),
    # ('fresh','ten','sup_figure1(a).png'),
    # ('salty','ten','sup_figure1(b).png'),
]
xfill = {
    'fresh':(np.datetime64('2015-02-01'),np.datetime64('2015-03-01')),
    'salty':(np.datetime64('2006-05-01'),np.datetime64('2006-08-01')),
}

# %%
# case = 'salty'
# duration = 'five'
# save_as = 'figure4(b).png'
for case, duration, save_as in meta:

    plt.clf()
    pre = 'lineplotprep/'+case+'_'
    if duration == 'five':
        time_slice = slice(1824,None,-1)
    elif duration == 'ten':
        time_slice = slice(None,None,-1)
    else:
        raise ValueError('duration not precalculated')
    str_slc = str(time_slice)
    
    if case == 'salty':
        TOTAL_VOLUME,NUMBER_OF_PARTICLE,VOLUME_EACH,idate = TOTAL_VOLUME_salty,NUMBER_OF_PARTICLE_salty,VOLUME_EACH_salty,salty_idate
    if case == 'fresh':
        TOTAL_VOLUME,NUMBER_OF_PARTICLE,VOLUME_EACH,idate = TOTAL_VOLUME_fresh,NUMBER_OF_PARTICLE_fresh,VOLUME_EACH_fresh,fresh_idate
    mean = xr.open_zarr(pre+'mean'+str_slc)
    std = xr.open_zarr(pre+'std'+str_slc)
    xtime = rtime[idate:idate-len(mean.time):-1]
    
    ax = plt.axes()
    handles = []
    labels = []
    for var in rhs_list:
        print(var)
        a_mean = -mean[var][::-1]
        a_std = 10*std[var][::-1]/np.sqrt(NUMBER_OF_PARTICLE-1)
        mean_line, = ax.plot(xtime, a_mean, label=case_term_dic[var], color=color_dic[var])
        spread_area = ax.fill_between(xtime, a_mean - a_std, a_mean + a_std, alpha=0.3, label=case_term_dic[var], color=color_dic[var])
        handles.append((mean_line, spread_area))
        labels.append(case_term_dic[var])
    mean['tot'] = (mean['A']+mean['e_ua']+mean['E']+mean['dif_h']+mean['dif_v']+mean['I']+mean['F'])
    offset = float(mean['sf'][0])
    salt = np.diff(np.array([0]+list(mean['sl'].data)))
    to_explain = salt - offset
    error = to_explain + mean['tot']
    mean_line, = ax.plot(xtime, error[::-1], color=error_color)
    handles.append(mean_line)
    labels.append('Error')
    ax2 = ax.twinx()
    ax2.set_ylim(ax.get_ylim()[0] + offset, ax.get_ylim()[1] + offset)
    if case == 'salty':
        sal_color = salty_theme_color
    elif case == 'fresh':
        sal_color = fresh_theme_color
    salt_line, = ax.plot(xtime, salt[::-1]-offset,color = sal_color)
    handles.append(salt_line)
    labels.append('Salinity Anomaly')
    # invisible_line, = plt.plot([],[],c = 'none')
    legend = ax.legend(handles,labels,fontsize = 7,loc = 0)
    legend.set_title(extra_text)
    plt.setp(legend.get_title(),fontsize=7)

    ylim = plt.gca().get_ylim()
    plt.fill_betweenx(ylim,[xfill[case][0]]*2,[xfill[case][1]]*2,**fill_betweenx_kwarg)
    plt.ylim(*ylim)
    if save_as:
        plt.savefig(save_as,dpi = dpi)
# Out:
# A
# F
# dif_v
# dif_h
# E
# e_ua
# I

# %%
# case = 'salty'
# duration = 'five'
# save_as = 'figure4(b).png'
# for case, duration, save_as in meta:

plt.clf()
pre = 'lineplotprep/salty_mean_traj_'
time_slice = slice(1824,None,-1)

str_slc = str(time_slice)

# if case == 'salty':
#     TOTAL_VOLUME,NUMBER_OF_PARTICLE,VOLUME_EACH,idate = TOTAL_VOLUME_salty,NUMBER_OF_PARTICLE_salty,VOLUME_EACH_salty,salty_idate
TOTAL_VOLUME = TOTAL_VOLUME_salty
NUMBER_OF_PARTICLE = 5e4
VOLUME_EACH = TOTAL_VOLUME/NUMBER_OF_PARTICLE
idate = salty_idate
# if case == 'fresh':
#     TOTAL_VOLUME,NUMBER_OF_PARTICLE,VOLUME_EACH,idate = TOTAL_VOLUME_fresh,NUMBER_OF_PARTICLE_fresh,VOLUME_EACH_fresh,fresh_idate
mean = xr.open_zarr(pre+'mean'+str_slc)
std = xr.open_zarr(pre+'std'+str_slc)
xtime = rtime[idate:idate-len(mean.time):-1]

ax = plt.axes()
handles = []
labels = []
for var in rhs_list:
    print(var)
    a_mean = -mean[var][::-1]
    a_std = std[var][::-1]/np.sqrt(NUMBER_OF_PARTICLE-1)
    mean_line, = ax.plot(xtime, a_mean, label=case_term_dic[var], color=color_dic[var])
    spread_area = ax.fill_between(xtime, a_mean - a_std, a_mean + a_std, alpha=0.3, label=case_term_dic[var], color=color_dic[var])
    handles.append((mean_line, spread_area))
    labels.append(case_term_dic[var])
mean['tot'] = (mean['A']+mean['e_ua']+mean['E']+mean['dif_h']+mean['dif_v']+mean['I']+mean['F'])
offset = float(mean['sf'][0])
salt = np.diff(np.array([0]+list(mean['sl'].data)))
to_explain = salt - offset
error = to_explain + mean['tot']
mean_line, = ax.plot(xtime, error[::-1], color=error_color)
handles.append(mean_line)
labels.append('Error')
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim()[0] + offset, ax.get_ylim()[1] + offset)
# if case == 'salty':
sal_color = salty_theme_color
# elif case == 'fresh':
#     sal_color = fresh_theme_color
salt_line, = ax.plot(xtime, salt[::-1]-offset,color = sal_color)
handles.append(salt_line)
labels.append('Salinity Anomaly')
# invisible_line, = plt.plot([],[],c = 'none')
legend = ax.legend(handles,labels,fontsize = 7,loc = 0)
# legend.set_title(extra_text)
plt.setp(legend.get_title(),fontsize=7)

ylim = plt.gca().get_ylim()
# plt.fill_betweenx(ylim,[xfill[case][0]]*2,[xfill[case][1]]*2,**fill_betweenx_kwarg)
plt.ylim(*ylim)
# if save_as:
#     plt.savefig(save_as,dpi = dpi)
# Out:
# A
# F
# dif_v
# E
# dif_h
# e_ua
# I
# (-0.12444323658966597, 0.14101995678003032)

# %%
# case = 'salty'
# duration = 'five'
# save_as = 'figure4(b).png'
# for case, duration, save_as in meta:

plt.clf()
pre = 'lineplotprep/fresh_mean_traj_'
time_slice = slice(1824,None,-1)

str_slc = str(time_slice)

# if case == 'salty':
#     TOTAL_VOLUME,NUMBER_OF_PARTICLE,VOLUME_EACH,idate = TOTAL_VOLUME_salty,NUMBER_OF_PARTICLE_salty,VOLUME_EACH_salty,salty_idate
TOTAL_VOLUME = TOTAL_VOLUME_fresh
NUMBER_OF_PARTICLE = 49998
VOLUME_EACH = TOTAL_VOLUME/NUMBER_OF_PARTICLE
idate = fresh_idate
# if case == 'fresh':
#     TOTAL_VOLUME,NUMBER_OF_PARTICLE,VOLUME_EACH,idate = TOTAL_VOLUME_fresh,NUMBER_OF_PARTICLE_fresh,VOLUME_EACH_fresh,fresh_idate
mean = xr.open_zarr(pre+'mean'+str_slc)
std = xr.open_zarr(pre+'std'+str_slc)
xtime = rtime[idate:idate-len(mean.time):-1]

ax = plt.axes()
handles = []
labels = []
for var in rhs_list:
    print(var)
    a_mean = -mean[var][::-1]
    a_std = std[var][::-1]/np.sqrt(NUMBER_OF_PARTICLE-1)
    mean_line, = ax.plot(xtime, a_mean, label=case_term_dic[var], color=color_dic[var])
    spread_area = ax.fill_between(xtime, a_mean - a_std, a_mean + a_std, alpha=0.3, label=case_term_dic[var], color=color_dic[var])
    handles.append((mean_line, spread_area))
    labels.append(case_term_dic[var])
mean['tot'] = (mean['A']+mean['e_ua']+mean['E']+mean['dif_h']+mean['dif_v']+mean['I']+mean['F'])
offset = float(mean['sf'][0])
salt = np.diff(np.array([0]+list(mean['sl'].data)))
to_explain = salt - offset
error = to_explain + mean['tot']
mean_line, = ax.plot(xtime, error[::-1], color=error_color)
handles.append(mean_line)
labels.append('Error')
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim()[0] + offset, ax.get_ylim()[1] + offset)
# if case == 'salty':
sal_color = fresh_theme_color
# elif case == 'fresh':
#     sal_color = fresh_theme_color
salt_line, = ax.plot(xtime, salt[::-1]-offset,color = sal_color)
handles.append(salt_line)
labels.append('Salinity Anomaly')
# invisible_line, = plt.plot([],[],c = 'none')
legend = ax.legend(handles,labels,fontsize = 7,loc = 0)
# legend.set_title(extra_text)
plt.setp(legend.get_title(),fontsize=7)

ylim = plt.gca().get_ylim()
# plt.fill_betweenx(ylim,[xfill[case][0]]*2,[xfill[case][1]]*2,**fill_betweenx_kwarg)
plt.ylim(*ylim)
# if save_as:
#     plt.savefig(save_as,dpi = dpi)
# Out:
# A
# F
# dif_v
# E
# dif_h
# e_ua
# I
# (-0.20824639345614912, 0.034094622761092125)

# %%
import os
os.listdir('/home/wjiang33/plot_production/lineplotprep/neutral2012_mean_traj_meanslice(1824, None, -1)')
mean = xr.open_zarr('/home/wjiang33/plot_production/lineplotprep/neutral2012_mean_traj_meanslice(1824, None, -1)')

# %%
'/home/wjiang33/plot_production/lineplotprep/netral2012_mean_traj_meanslice(1824, None, -1)'
'/home/wjiang33/plot_production/lineplotprep/neutral2012_mean_traj_meanslice(1824, None, -1)'

# %%
mean
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1825)
# Dimensions without coordinates: time
# Data variables: (12/13)
#     A        (time) float64 dask.array<chunksize=(1825,), meta=np.ndarray>
#     E        (time) float64 dask.array<chunksize=(1825,), meta=np.ndarray>
#     F        (time) float64 dask.array<chunksize=(1825,), meta=np.ndarray>
#     I        (time) float64 dask.array<chunksize=(1825,), meta=np.ndarray>
#     dep      (time) float64 dask.array<chunksize=(1825,), meta=np.ndarray>
#     dif_h    (time) float64 dask.array<chunksize=(1825,), meta=np.ndarray>
#     ...       ...
#     e_ua     (time) float64 dask.array<chunksize=(1825,), meta=np.ndarray>
#     lat      (time) float64 dask.array<chunksize=(1825,), meta=np.ndarray>
#     lhs      (time) float64 dask.array<chunksize=(1825,), meta=np.ndarray>
#     lon      (time) float64 dask.array<chunksize=(1825,), meta=np.ndarray>
#     sf       (time) float64 dask.array<chunksize=(1825,), meta=np.ndarray>
#     sl       (time) float64 dask.array<chunksize=(1825,), meta=np.ndarray>

# %%
# case = 'salty'
# duration = 'five'
# save_as = 'figure4(b).png'
# for case, duration, save_as in meta:

plt.clf()
pre = 'lineplotprep/neutral2012_mean_traj_'
time_slice = slice(1824,None,-1)

str_slc = str(time_slice)

# if case == 'salty':
#     TOTAL_VOLUME,NUMBER_OF_PARTICLE,VOLUME_EACH,idate = TOTAL_VOLUME_salty,NUMBER_OF_PARTICLE_salty,VOLUME_EACH_salty,salty_idate
# TOTAL_VOLUME = TOTAL_VOLUME_fresh
NUMBER_OF_PARTICLE = 45336
# VOLUME_EACH = TOTAL_VOLUME/NUMBER_OF_PARTICLE
idate = 7365
# if case == 'fresh':
#     TOTAL_VOLUME,NUMBER_OF_PARTICLE,VOLUME_EACH,idate = TOTAL_VOLUME_fresh,NUMBER_OF_PARTICLE_fresh,VOLUME_EACH_fresh,fresh_idate
mean = xr.open_zarr(pre+'mean'+str_slc)
std = xr.open_zarr(pre+'std'+str_slc)
xtime = rtime[idate:idate-len(mean.time):-1]

ax = plt.axes()
handles = []
labels = []
for var in rhs_list:
    print(var)
    a_mean = -mean[var][::-1]
    a_std = std[var][::-1]/np.sqrt(NUMBER_OF_PARTICLE-1)
    mean_line, = ax.plot(xtime, a_mean, label=case_term_dic[var], color=color_dic[var])
    spread_area = ax.fill_between(xtime, a_mean - a_std, a_mean + a_std, alpha=0.3, label=case_term_dic[var], color=color_dic[var])
    handles.append((mean_line, spread_area))
    labels.append(case_term_dic[var])
mean['tot'] = (mean['A']+mean['e_ua']+mean['E']+mean['dif_h']+mean['dif_v']+mean['I']+mean['F'])
offset = float(mean['sf'][0])
salt = np.diff(np.array([0]+list(mean['sl'].data)))
to_explain = salt - offset
error = to_explain + mean['tot']
mean_line, = ax.plot(xtime, error[::-1], color=error_color)
handles.append(mean_line)
labels.append('Error')
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim()[0] + offset, ax.get_ylim()[1] + offset)
# if case == 'salty':
sal_color = salty_theme_color
# elif case == 'fresh':
#     sal_color = fresh_theme_color
salt_line, = ax.plot(xtime, salt[::-1]-offset,color = sal_color)
handles.append(salt_line)
labels.append('Salinity Anomaly')
# invisible_line, = plt.plot([],[],c = 'none')
legend = ax.legend(handles,labels,fontsize = 7,loc = 0)
# legend.set_title(extra_text)
plt.setp(legend.get_title(),fontsize=7)

ylim = plt.gca().get_ylim()
# plt.fill_betweenx(ylim,[xfill[case][0]]*2,[xfill[case][1]]*2,**fill_betweenx_kwarg)
plt.ylim(*ylim)
# if save_as:
#     plt.savefig(save_as,dpi = dpi)
# Out:
# A
# F
# dif_v
# E
# dif_h
# e_ua
# I
# (-0.08892456289655866, 0.058972288534760636)

# %%
# case = 'salty'
# duration = 'five'
# save_as = 'figure4(b).png'
# for case, duration, save_as in meta:

plt.clf()
pre = 'lineplotprep/neutral2012_time_traj_'
time_slice = slice(1824,None,-1)

str_slc = str(time_slice)

# if case == 'salty':
#     TOTAL_VOLUME,NUMBER_OF_PARTICLE,VOLUME_EACH,idate = TOTAL_VOLUME_salty,NUMBER_OF_PARTICLE_salty,VOLUME_EACH_salty,salty_idate
# TOTAL_VOLUME = TOTAL_VOLUME_fresh
NUMBER_OF_PARTICLE = 45336
# VOLUME_EACH = TOTAL_VOLUME/NUMBER_OF_PARTICLE
idate = 7365
# if case == 'fresh':
#     TOTAL_VOLUME,NUMBER_OF_PARTICLE,VOLUME_EACH,idate = TOTAL_VOLUME_fresh,NUMBER_OF_PARTICLE_fresh,VOLUME_EACH_fresh,fresh_idate
mean = xr.open_zarr(pre+'mean'+str_slc)
std = xr.open_zarr(pre+'std'+str_slc)
xtime = rtime[idate:idate-len(mean.time):-1]

ax = plt.axes()
handles = []
labels = []
for var in rhs_list:
    print(var)
    a_mean = -mean[var][::-1]
    a_std = std[var][::-1]/np.sqrt(NUMBER_OF_PARTICLE-1)
    mean_line, = ax.plot(xtime, a_mean, label=case_term_dic[var], color=color_dic[var])
    spread_area = ax.fill_between(xtime, a_mean - a_std, a_mean + a_std, alpha=0.3, label=case_term_dic[var], color=color_dic[var])
    handles.append((mean_line, spread_area))
    labels.append(case_term_dic[var])
mean['tot'] = (mean['A']+mean['e_ua']+mean['E']+mean['dif_h']+mean['dif_v']+mean['I']+mean['F'])
offset = float(mean['sf'][0])
salt = np.diff(np.array([0]+list(mean['sl'].data)))
to_explain = salt - offset
error = to_explain + mean['tot']
mean_line, = ax.plot(xtime, error[::-1], color=error_color)
handles.append(mean_line)
labels.append('Error')
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim()[0] + offset, ax.get_ylim()[1] + offset)
# if case == 'salty':
sal_color = salty_theme_color
# elif case == 'fresh':
#     sal_color = fresh_theme_color
salt_line, = ax.plot(xtime, salt[::-1]-offset,color = sal_color)
handles.append(salt_line)
labels.append('Salinity Anomaly')
# invisible_line, = plt.plot([],[],c = 'none')
legend = ax.legend(handles,labels,fontsize = 7,loc = 0)
# legend.set_title(extra_text)
plt.setp(legend.get_title(),fontsize=7)

ylim = plt.gca().get_ylim()
# plt.fill_betweenx(ylim,[xfill[case][0]]*2,[xfill[case][1]]*2,**fill_betweenx_kwarg)
plt.ylim(*ylim)
# if save_as:
#     plt.savefig(save_as,dpi = dpi)
# Out:
# A
# F
# dif_v
# E
# dif_h
# e_ua
# I
# (-0.07432315039062688, 0.053494991717058474)

# %%
# case = 'salty'
# duration = 'five'
# save_as = 'figure4(b).png'
# for case, duration, save_as in meta:

plt.clf()
pre = 'lineplotprep/neutral2001_mean_traj_'
time_slice = slice(1824,None,-1)

str_slc = str(time_slice)

# if case == 'salty':
#     TOTAL_VOLUME,NUMBER_OF_PARTICLE,VOLUME_EACH,idate = TOTAL_VOLUME_salty,NUMBER_OF_PARTICLE_salty,VOLUME_EACH_salty,salty_idate
# TOTAL_VOLUME = TOTAL_VOLUME_fresh
NUMBER_OF_PARTICLE = 45336
# VOLUME_EACH = TOTAL_VOLUME/NUMBER_OF_PARTICLE
idate = 3561
# if case == 'fresh':
#     TOTAL_VOLUME,NUMBER_OF_PARTICLE,VOLUME_EACH,idate = TOTAL_VOLUME_fresh,NUMBER_OF_PARTICLE_fresh,VOLUME_EACH_fresh,fresh_idate
mean = xr.open_zarr(pre+'mean'+str_slc)
std = xr.open_zarr(pre+'std'+str_slc)
xtime = rtime[idate:idate-len(mean.time):-1]

ax = plt.axes()
handles = []
labels = []
for var in rhs_list:
    print(var)
    a_mean = -mean[var][::-1]
    a_std = std[var][::-1]/np.sqrt(NUMBER_OF_PARTICLE-1)
    mean_line, = ax.plot(xtime, a_mean, label=case_term_dic[var], color=color_dic[var])
    spread_area = ax.fill_between(xtime, a_mean - a_std, a_mean + a_std, alpha=0.3, label=case_term_dic[var], color=color_dic[var])
    handles.append((mean_line, spread_area))
    labels.append(case_term_dic[var])
mean['tot'] = (mean['A']+mean['e_ua']+mean['E']+mean['dif_h']+mean['dif_v']+mean['I']+mean['F'])
offset = float(mean['sf'][0])
salt = np.diff(np.array([0]+list(mean['sl'].data)))
to_explain = salt - offset
error = to_explain + mean['tot']
mean_line, = ax.plot(xtime, error[::-1], color=error_color)
handles.append(mean_line)
labels.append('Error')
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim()[0] + offset, ax.get_ylim()[1] + offset)
# if case == 'salty':
sal_color = salty_theme_color
# elif case == 'fresh':
#     sal_color = fresh_theme_color
salt_line, = ax.plot(xtime, salt[::-1]-offset,color = sal_color)
handles.append(salt_line)
labels.append('Salinity Anomaly')
# invisible_line, = plt.plot([],[],c = 'none')
legend = ax.legend(handles,labels,fontsize = 7,loc = 0)
# legend.set_title(extra_text)
plt.setp(legend.get_title(),fontsize=7)

ylim = plt.gca().get_ylim()
# plt.fill_betweenx(ylim,[xfill[case][0]]*2,[xfill[case][1]]*2,**fill_betweenx_kwarg)
plt.ylim(*ylim)
# if save_as:
#     plt.savefig(save_as,dpi = dpi)
# Out:
# A
# F
# dif_v
# E
# dif_h
# e_ua
# I
# (-0.06151376821209649, 0.015250330100724775)

# %%
# case = 'salty'
# duration = 'five'
# save_as = 'figure4(b).png'
# for case, duration, save_as in meta:

plt.clf()
pre = 'lineplotprep/neutral2001_time_traj_'
time_slice = slice(1824,None,-1)

str_slc = str(time_slice)

# if case == 'salty':
#     TOTAL_VOLUME,NUMBER_OF_PARTICLE,VOLUME_EACH,idate = TOTAL_VOLUME_salty,NUMBER_OF_PARTICLE_salty,VOLUME_EACH_salty,salty_idate
# TOTAL_VOLUME = TOTAL_VOLUME_fresh
NUMBER_OF_PARTICLE = 45336
# VOLUME_EACH = TOTAL_VOLUME/NUMBER_OF_PARTICLE
idate = 3561
# if case == 'fresh':
#     TOTAL_VOLUME,NUMBER_OF_PARTICLE,VOLUME_EACH,idate = TOTAL_VOLUME_fresh,NUMBER_OF_PARTICLE_fresh,VOLUME_EACH_fresh,fresh_idate
mean = xr.open_zarr(pre+'mean'+str_slc)
std = xr.open_zarr(pre+'std'+str_slc)
xtime = rtime[idate:idate-len(mean.time):-1]

ax = plt.axes()
handles = []
labels = []
for var in rhs_list:
    print(var)
    a_mean = -mean[var][::-1]
    a_std = std[var][::-1]/np.sqrt(NUMBER_OF_PARTICLE-1)
    mean_line, = ax.plot(xtime, a_mean, label=case_term_dic[var], color=color_dic[var])
    spread_area = ax.fill_between(xtime, a_mean - a_std, a_mean + a_std, alpha=0.3, label=case_term_dic[var], color=color_dic[var])
    handles.append((mean_line, spread_area))
    labels.append(case_term_dic[var])
mean['tot'] = (mean['A']+mean['e_ua']+mean['E']+mean['dif_h']+mean['dif_v']+mean['I']+mean['F'])
offset = float(mean['sf'][0])
salt = np.diff(np.array([0]+list(mean['sl'].data)))
to_explain = salt - offset
error = to_explain + mean['tot']
mean_line, = ax.plot(xtime, error[::-1], color=error_color)
handles.append(mean_line)
labels.append('Error')
ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim()[0] + offset, ax.get_ylim()[1] + offset)
# if case == 'salty':
sal_color = salty_theme_color
# elif case == 'fresh':
#     sal_color = fresh_theme_color
salt_line, = ax.plot(xtime, salt[::-1]-offset,color = sal_color)
handles.append(salt_line)
labels.append('Salinity Anomaly')
# invisible_line, = plt.plot([],[],c = 'none')
legend = ax.legend(handles,labels,fontsize = 7,loc = 0)
# legend.set_title(extra_text)
plt.setp(legend.get_title(),fontsize=7)

ylim = plt.gca().get_ylim()
# plt.fill_betweenx(ylim,[xfill[case][0]]*2,[xfill[case][1]]*2,**fill_betweenx_kwarg)
plt.ylim(*ylim)
# if save_as:
#     plt.savefig(save_as,dpi = dpi)
# Out:
# A
# F
# dif_v
# E
# dif_h
# e_ua
# I
# (-0.06624678653495775, 0.01092668427286702)

# %%
ax.get_ylim()

# %%
offset

# %%
mean['sf'][0].values

# %%
table.F

# %%
plt.imshow(table.dif_h[::10,::10000])

# %%
table.dif_h.max().values

# %%
table.dif_h.min().values

# %%
hey = abs(table.dif_h).max(axis = 1).values

# %%
hello = (table.dif_h).std(axis = 1).values

# %%
difh_mean = (table.dif_h).mean(axis = 1).values

# %%
hey

# %%
plt.plot(hey)

# %%
plt.plot(hello)

# %%
plt.plot(np.cumsum(difh_mean[::-1]))

# %%
xtime
